# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./data/dataset_cal.csv')

# %%
S1 = data.loc[data['Subject'] == 'S1']
S2 = data.loc[data['Subject'] == 'S2']
S3 = data.loc[data['Subject'] == 'S3']
S4 = data.loc[data['Subject'] == 'S4']
S5 = data.loc[data['Subject'] == 'S5']
S6 = data.loc[data['Subject'] == 'S6']
S7 = data.loc[data['Subject'] == 'S7']
S8 = data.loc[data['Subject'] == 'S8']
S9 = data.loc[data['Subject'] == 'S9']
S10 = data.loc[data['Subject'] == 'S10']
S11 = data.loc[data['Subject'] == 'S11']
S12 = data.loc[data['Subject'] == 'S12']
S13 = data.loc[data['Subject'] == 'S13']
S14 = data.loc[data['Subject'] == 'S14']
S15 = data.loc[data['Subject'] == 'S15']
S_groups = [S1, S2, S3, S4, S5, S6, S7, S8, S9, S10, S11, S12, S13, S14, S15]

# %%
def convert_train(dataset):
    dataset['Gender'].replace(' f', 0, inplace=True)
    dataset['Gender'].replace(' m', 1, inplace=True)
    dataset.drop(columns = ['WEIGHT','Gender', 'AGE', 'HEIGHT', 'SKIN', 'SPORT', 'Activity','Subject' ], inplace = True)
    return dataset

for i in S_groups:
    convert_train(i)
# Out:
# c:\Users\Conler\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# c:\Users\Conler\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
S1_y = S1['label'].astype(np.float32)
S1_X = S1.drop(columns = ['label'],inplace = False).astype(np.float32)
S2_y = S2['label'].astype(np.float32)
S2_X = S2.drop(columns = ['label'],inplace = False).astype(np.float32)
S3_y = S3['label'].astype(np.float32)
S3_X = S3.drop(columns = ['label'],inplace = False).astype(np.float32)
S4_y = S4['label'].astype(np.float32)
S4_X = S4.drop(columns = ['label'],inplace = False).astype(np.float32)
S5_y = S5['label'].astype(np.float32)
S5_X = S5.drop(columns = ['label'],inplace = False).astype(np.float32)
S6_y = S6['label'].astype(np.float32)
S6_X = S6.drop(columns = ['label'],inplace = False).astype(np.float32)
S7_y = S7['label'].astype(np.float32)
S7_X = S7.drop(columns = ['label'],inplace = False).astype(np.float32)
S8_y = S8['label'].astype(np.float32)
S8_X = S8.drop(columns = ['label'],inplace = False).astype(np.float32)
S9_y = S9['label'].astype(np.float32)
S9_X = S9.drop(columns = ['label'],inplace = False).astype(np.float32)
S10_y = S10['label'].astype(np.float32)
S10_X = S10.drop(columns = ['label'],inplace = False).astype(np.float32)
S11_y = S11['label'].astype(np.float32)
S11_X = S11.drop(columns = ['label'],inplace = False).astype(np.float32)
S12_y = S12['label'].astype(np.float32)
S12_X = S12.drop(columns = ['label'],inplace = False).astype(np.float32)
S13_y = S13['label'].astype(np.float32)
S13_X = S13.drop(columns = ['label'],inplace = False).astype(np.float32)
S14_y = S14['label'].astype(np.float32)
S14_X = S14.drop(columns = ['label'],inplace = False).astype(np.float32)
S15_y = S15['label'].astype(np.float32)
S15_X = S15.drop(columns = ['label'],inplace = False).astype(np.float32)

# %%
remove = ["Subject", "Activity"]
features = [column for column in list(data.columns) if column not in remove]

# %%
data['Gender'].replace(' f', 0, inplace=True)
data['Gender'].replace(' m', 1, inplace=True)
data
# Out:
#            label  chest_ACC_x_mean  chest_ACC_y_mean  chest_ACC_z_mean  \
# 0      49.611369          0.851230         -0.066021         -0.369793
# 1      50.323992          0.853035         -0.064653         -0.372883
# 2      52.708336          0.862127         -0.063661         -0.328341
# 3      55.640794          0.884370         -0.063035         -0.265127
# 4      57.658406          0.889886         -0.042930         -0.247533
# ...          ...               ...               ...               ...
# 64692  75.475622          0.894839          0.011158         -0.214601
# 64693  77.524511          0.895650          0.014221         -0.217153
# 64694  78.714945          0.893826          0.022179         -0.202851
# 64695  80.413954          0.896889          0.022090         -0.203860
# 64696  80.853007          0.892864          0.013154         -0.226432
#
#        chest_ECG_mean  chest_Resp_mean  wrist_ACC_x_mean  wrist_ACC_y_mean  \
# ...

# %%
data.drop(columns = ['WEIGHT','Gender', 'AGE', 'HEIGHT', 'SKIN', 'SPORT', 'Activity','Subject' ], inplace = True)

# %%
data.corr()
# Out:
#                        label  chest_ACC_x_mean  chest_ACC_y_mean  \
# label               1.000000          0.154025         -0.000177
# chest_ACC_x_mean    0.154025          1.000000         -0.225537
# chest_ACC_y_mean   -0.000177         -0.225537          1.000000
# chest_ACC_z_mean    0.314287          0.495670         -0.079242
# chest_ECG_mean     -0.001278          0.002326          0.007154
# chest_Resp_mean     0.000767         -0.001566         -0.000595
# wrist_ACC_x_mean    0.155507         -0.056454          0.029836
# wrist_ACC_y_mean    0.265899          0.132357          0.038897
# wrist_ACC_z_mean   -0.150280         -0.253948          0.048081
# wrist_EDA_mean      0.241833         -0.063959          0.214721
# wrist_BVP_mean     -0.001084          0.002323          0.002732
# wrist_TEMP_mean     0.058725         -0.005428          0.126306
# chest_ACC_x_std     0.450431          0.239172          0.033136
# ...

# %%
y = data['label']
X = data.drop(columns = ['label'],inplace = False)

# %%
y.astype(np.float32)
X.astype(np.float32)
# Out:
#        chest_ACC_x_mean  chest_ACC_y_mean  chest_ACC_z_mean  chest_ECG_mean  \
# 0              0.851230         -0.066021         -0.369793        0.039022
# 1              0.853035         -0.064653         -0.372883       -0.037044
# 2              0.862127         -0.063661         -0.328341        0.021329
# 3              0.884370         -0.063035         -0.265127        0.006393
# 4              0.889886         -0.042930         -0.247533       -0.024418
# ...                 ...               ...               ...             ...
# 64692          0.894839          0.011158         -0.214601       -0.008444
# 64693          0.895650          0.014221         -0.217153        0.000331
# 64694          0.893826          0.022179         -0.202851        0.021754
# 64695          0.896889          0.022090         -0.203860       -0.013849
# 64696          0.892864          0.013154         -0.226432       -0.002727
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train,  y_val = train_test_split(X, y, test_size=0.4, random_state=42)
print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (38818, 34) (38818,) (25879, 34) (25879,)

# %%
## Change shape
X_train = np.expand_dims(X_train, -1)
X_val = np.expand_dims(X_val, -1)

print(X_train.shape, X_val.shape)

input_dim = X_train.shape[1:]
# Out:
# (38818, 34, 1) (25879, 34, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution1D, Activation, Flatten, Dense, LeakyReLU, MaxPooling1D
from tensorflow.keras.optimizers import RMSprop, Adam

# %%
model = Sequential()
model.add(Convolution1D(filters=64, kernel_size=2, input_shape=input_dim))
model.add(MaxPooling1D(pool_size=2))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(1, activation="elu"))
model.compile(optimizer=Adam(learning_rate=0.01), loss="mean_absolute_error")
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv1d (Conv1D)             (None, 33, 64)            192
#
#  max_pooling1d (MaxPooling1D  (None, 16, 64)           0
#  )
#
#  max_pooling1d_1 (MaxPooling  (None, 8, 64)            0
#  1D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 1)                 513
#
# ...
# Total params: 705
# Trainable params: 705
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=100, verbose=1, validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 389/389 [==============================] - 1s 2ms/step - loss: 17.1990 - val_loss: 14.0038
# Epoch 2/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.8359 - val_loss: 13.5347
# Epoch 3/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.4935 - val_loss: 13.2594
# Epoch 4/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.4319 - val_loss: 13.1136
# Epoch 5/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.3159 - val_loss: 13.2029
# Epoch 6/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.2731 - val_loss: 13.1068
# Epoch 7/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.3013 - val_loss: 13.3114
# Epoch 8/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.2319 - val_loss: 13.5323
# Epoch 9/100
# 389/389 [==============================] - 1s 2ms/step - loss: 13.1145 - val_loss: 13.1090
# Epoch 10/100
# ...

# %%
model.evaluate(X_val, y_val)
# Out:
# 809/809 [==============================] - 0s 444us/step - loss: 12.9179
# 12.917865753173828

# %%
model.evaluate(S1_X,S1_y)
model.evaluate(S2_X,S2_y)
model.evaluate(S3_X,S3_y)
model.evaluate(S4_X,S4_y)
model.evaluate(S5_X,S5_y)
model.evaluate(S6_X,S6_y)
model.evaluate(S7_X,S7_y)
model.evaluate(S8_X,S8_y)
model.evaluate(S9_X,S9_y)
model.evaluate(S10_X,S10_y)
model.evaluate(S11_X,S11_y)
model.evaluate(S12_X,S12_y)
model.evaluate(S13_X,S13_y)
model.evaluate(S14_X,S14_y)
model.evaluate(S15_X,S15_y)
# Out:
# ...
# 124/124 [==============================] - 0s 635us/step - loss: 8.2486
# 8.248619079589844
